# %%
import pandas as pd
import numpy as np

# %%
cij = pd.read_excel("cij.xlsx",sheet_name="总运费").iloc[:,1:]
cij = cij.replace("inf",value = np.inf)
cij
# Out:
#        S1     S2     S3     S4     S5     S6     S7
# 0     inf    inf    inf    inf    inf    inf    inf
# 1   160.3  210.3  220.3  255.3  225.3  255.3  265.3
# 2   140.2  190.2  200.2  235.2  245.2  235.2  250.2
# 3    86.0  136.0  146.0  181.0  171.0  181.0  191.0
# 4    38.0  111.0  121.0  156.0  146.0  156.0  166.0
# 5    20.5   95.5  105.5  140.5  130.5  140.5  150.5
# 6    21.0   86.0   96.0  131.0  121.0  131.0  141.0
# 7    21.2   76.2   86.2  121.2  111.2  121.2  131.2
# 8    64.2  114.2   48.2   84.2   79.2   89.2   99.2
# 9    92.0  142.0   82.0   62.0   57.0   62.0   77.0
# 10  101.0  131.0   86.0   51.0   33.0   51.0   66.0
# 11  106.0  156.0   96.0   61.0   51.0   45.0   56.0
# 12  121.2  171.2  111.2   76.2   71.2   26.2   38.2
# 13  128.0  178.0  118.0   83.0   73.0   31.0   26.0
# 14  142.0  192.0  132.0   97.0   87.0   28.0   22.0

# %%
from ortools.linear_solver import pywraplp
solver = pywraplp.Solver.CreateSolver('SCIP')

# %%
y1 = solver.IntVar(0, 1, 'y1')
y2 = solver.IntVar(0, 1, 'y2')
y3 = solver.IntVar(0, 1, 'y3')
y4 = solver.IntVar(0, 1, 'y4')
y5 = solver.IntVar(0, 1, 'y5')
y6 = solver.IntVar(0, 1, 'y6')
y7 = solver.IntVar(0, 1, 'y7')

infty = solver.infinity()

z_1_1_p = solver.NumVar(0, infty, "z_1_1_p")
z_1_1_n = solver.NumVar(0, infty, "z_1_1_n")
z_1_2_p = solver.NumVar(0, infty, "z_1_2_p")
z_1_2_n = solver.NumVar(0, infty, "z_1_2_n")
z_1_3_p = solver.NumVar(0, infty, "z_1_3_p")
z_1_3_n = solver.NumVar(0, infty, "z_1_3_n")
z_1_4_p = solver.NumVar(0, infty, "z_1_4_p")
z_1_4_n = solver.NumVar(0, infty, "z_1_4_n")
z_1_5_p = solver.NumVar(0, infty, "z_1_5_p")
z_1_5_n = solver.NumVar(0, infty, "z_1_5_n")
z_1_6_p = solver.NumVar(0, infty, "z_1_6_p")
z_1_6_n = solver.NumVar(0, infty, "z_1_6_n")
z_1_7_p = solver.NumVar(0, infty, "z_1_7_p")
z_1_7_n = solver.NumVar(0, infty, "z_1_7_n")
z_1_8_p = solver.NumVar(0, infty, "z_1_8_p")
z_1_8_n = solver.NumVar(0, infty, "z_1_8_n")
z_1_9_p = solver.NumVar(0, infty, "z_1_9_p")
z_1_9_n = solver.NumVar(0, infty, "z_1_9_n")
z_1_10_p = solver.NumVar(0, infty, "z_1_10_p")
z_1_10_n = solver.NumVar(0, infty, "z_1_10_n")
z_1_11_p = solver.NumVar(0, infty, "z_1_11_p")
z_1_11_n = solver.NumVar(0, infty, "z_1_11_n")
z_1_12_p = solver.NumVar(0, infty, "z_1_12_p")
z_1_12_n = solver.NumVar(0, infty, "z_1_12_n")
z_1_13_p = solver.NumVar(0, infty, "z_1_13_p")
z_1_13_n = solver.NumVar(0, infty, "z_1_13_n")
z_1_14_p = solver.NumVar(0, infty, "z_1_14_p")
z_1_14_n = solver.NumVar(0, infty, "z_1_14_n")
z_1_15_p = solver.NumVar(0, infty, "z_1_15_p")
z_1_15_n = solver.NumVar(0, infty, "z_1_15_n")
z_2_1_p = solver.NumVar(0, infty, "z_2_1_p")
z_2_1_n = solver.NumVar(0, infty, "z_2_1_n")
z_2_2_p = solver.NumVar(0, infty, "z_2_2_p")
z_2_2_n = solver.NumVar(0, infty, "z_2_2_n")
z_2_3_p = solver.NumVar(0, infty, "z_2_3_p")
z_2_3_n = solver.NumVar(0, infty, "z_2_3_n")
z_2_4_p = solver.NumVar(0, infty, "z_2_4_p")
z_2_4_n = solver.NumVar(0, infty, "z_2_4_n")
z_2_5_p = solver.NumVar(0, infty, "z_2_5_p")
z_2_5_n = solver.NumVar(0, infty, "z_2_5_n")
z_2_6_p = solver.NumVar(0, infty, "z_2_6_p")
z_2_6_n = solver.NumVar(0, infty, "z_2_6_n")
z_2_7_p = solver.NumVar(0, infty, "z_2_7_p")
z_2_7_n = solver.NumVar(0, infty, "z_2_7_n")
z_2_8_p = solver.NumVar(0, infty, "z_2_8_p")
z_2_8_n = solver.NumVar(0, infty, "z_2_8_n")
z_2_9_p = solver.NumVar(0, infty, "z_2_9_p")
z_2_9_n = solver.NumVar(0, infty, "z_2_9_n")
z_2_10_p = solver.NumVar(0, infty, "z_2_10_p")
z_2_10_n = solver.NumVar(0, infty, "z_2_10_n")
z_2_11_p = solver.NumVar(0, infty, "z_2_11_p")
z_2_11_n = solver.NumVar(0, infty, "z_2_11_n")
z_2_12_p = solver.NumVar(0, infty, "z_2_12_p")
z_2_12_n = solver.NumVar(0, infty, "z_2_12_n")
z_2_13_p = solver.NumVar(0, infty, "z_2_13_p")
z_2_13_n = solver.NumVar(0, infty, "z_2_13_n")
z_2_14_p = solver.NumVar(0, infty, "z_2_14_p")
z_2_14_n = solver.NumVar(0, infty, "z_2_14_n")
z_2_15_p = solver.NumVar(0, infty, "z_2_15_p")
z_2_15_n = solver.NumVar(0, infty, "z_2_15_n")
z_3_1_p = solver.NumVar(0, infty, "z_3_1_p")
z_3_1_n = solver.NumVar(0, infty, "z_3_1_n")
z_3_2_p = solver.NumVar(0, infty, "z_3_2_p")
z_3_2_n = solver.NumVar(0, infty, "z_3_2_n")
z_3_3_p = solver.NumVar(0, infty, "z_3_3_p")
z_3_3_n = solver.NumVar(0, infty, "z_3_3_n")
z_3_4_p = solver.NumVar(0, infty, "z_3_4_p")
z_3_4_n = solver.NumVar(0, infty, "z_3_4_n")
z_3_5_p = solver.NumVar(0, infty, "z_3_5_p")
z_3_5_n = solver.NumVar(0, infty, "z_3_5_n")
z_3_6_p = solver.NumVar(0, infty, "z_3_6_p")
z_3_6_n = solver.NumVar(0, infty, "z_3_6_n")
z_3_7_p = solver.NumVar(0, infty, "z_3_7_p")
z_3_7_n = solver.NumVar(0, infty, "z_3_7_n")
z_3_8_p = solver.NumVar(0, infty, "z_3_8_p")
z_3_8_n = solver.NumVar(0, infty, "z_3_8_n")
z_3_9_p = solver.NumVar(0, infty, "z_3_9_p")
z_3_9_n = solver.NumVar(0, infty, "z_3_9_n")
z_3_10_p = solver.NumVar(0, infty, "z_3_10_p")
z_3_10_n = solver.NumVar(0, infty, "z_3_10_n")
z_3_11_p = solver.NumVar(0, infty, "z_3_11_p")
z_3_11_n = solver.NumVar(0, infty, "z_3_11_n")
z_3_12_p = solver.NumVar(0, infty, "z_3_12_p")
z_3_12_n = solver.NumVar(0, infty, "z_3_12_n")
z_3_13_p = solver.NumVar(0, infty, "z_3_13_p")
z_3_13_n = solver.NumVar(0, infty, "z_3_13_n")
z_3_14_p = solver.NumVar(0, infty, "z_3_14_p")
z_3_14_n = solver.NumVar(0, infty, "z_3_14_n")
z_3_15_p = solver.NumVar(0, infty, "z_3_15_p")
z_3_15_n = solver.NumVar(0, infty, "z_3_15_n")
z_4_1_p = solver.NumVar(0, infty, "z_4_1_p")
z_4_1_n = solver.NumVar(0, infty, "z_4_1_n")
z_4_2_p = solver.NumVar(0, infty, "z_4_2_p")
z_4_2_n = solver.NumVar(0, infty, "z_4_2_n")
z_4_3_p = solver.NumVar(0, infty, "z_4_3_p")
z_4_3_n = solver.NumVar(0, infty, "z_4_3_n")
z_4_4_p = solver.NumVar(0, infty, "z_4_4_p")
z_4_4_n = solver.NumVar(0, infty, "z_4_4_n")
z_4_5_p = solver.NumVar(0, infty, "z_4_5_p")
z_4_5_n = solver.NumVar(0, infty, "z_4_5_n")
z_4_6_p = solver.NumVar(0, infty, "z_4_6_p")
z_4_6_n = solver.NumVar(0, infty, "z_4_6_n")
z_4_7_p = solver.NumVar(0, infty, "z_4_7_p")
z_4_7_n = solver.NumVar(0, infty, "z_4_7_n")
z_4_8_p = solver.NumVar(0, infty, "z_4_8_p")
z_4_8_n = solver.NumVar(0, infty, "z_4_8_n")
z_4_9_p = solver.NumVar(0, infty, "z_4_9_p")
z_4_9_n = solver.NumVar(0, infty, "z_4_9_n")
z_4_10_p = solver.NumVar(0, infty, "z_4_10_p")
z_4_10_n = solver.NumVar(0, infty, "z_4_10_n")
z_4_11_p = solver.NumVar(0, infty, "z_4_11_p")
z_4_11_n = solver.NumVar(0, infty, "z_4_11_n")
z_4_12_p = solver.NumVar(0, infty, "z_4_12_p")
z_4_12_n = solver.NumVar(0, infty, "z_4_12_n")
z_4_13_p = solver.NumVar(0, infty, "z_4_13_p")
z_4_13_n = solver.NumVar(0, infty, "z_4_13_n")
z_4_14_p = solver.NumVar(0, infty, "z_4_14_p")
z_4_14_n = solver.NumVar(0, infty, "z_4_14_n")
z_4_15_p = solver.NumVar(0, infty, "z_4_15_p")
z_4_15_n = solver.NumVar(0, infty, "z_4_15_n")
z_5_1_p = solver.NumVar(0, infty, "z_5_1_p")
z_5_1_n = solver.NumVar(0, infty, "z_5_1_n")
z_5_2_p = solver.NumVar(0, infty, "z_5_2_p")
z_5_2_n = solver.NumVar(0, infty, "z_5_2_n")
z_5_3_p = solver.NumVar(0, infty, "z_5_3_p")
z_5_3_n = solver.NumVar(0, infty, "z_5_3_n")
z_5_4_p = solver.NumVar(0, infty, "z_5_4_p")
z_5_4_n = solver.NumVar(0, infty, "z_5_4_n")
z_5_5_p = solver.NumVar(0, infty, "z_5_5_p")
z_5_5_n = solver.NumVar(0, infty, "z_5_5_n")
z_5_6_p = solver.NumVar(0, infty, "z_5_6_p")
z_5_6_n = solver.NumVar(0, infty, "z_5_6_n")
z_5_7_p = solver.NumVar(0, infty, "z_5_7_p")
z_5_7_n = solver.NumVar(0, infty, "z_5_7_n")
z_5_8_p = solver.NumVar(0, infty, "z_5_8_p")
z_5_8_n = solver.NumVar(0, infty, "z_5_8_n")
z_5_9_p = solver.NumVar(0, infty, "z_5_9_p")
z_5_9_n = solver.NumVar(0, infty, "z_5_9_n")
z_5_10_p = solver.NumVar(0, infty, "z_5_10_p")
z_5_10_n = solver.NumVar(0, infty, "z_5_10_n")
z_5_11_p = solver.NumVar(0, infty, "z_5_11_p")
z_5_11_n = solver.NumVar(0, infty, "z_5_11_n")
z_5_12_p = solver.NumVar(0, infty, "z_5_12_p")
z_5_12_n = solver.NumVar(0, infty, "z_5_12_n")
z_5_13_p = solver.NumVar(0, infty, "z_5_13_p")
z_5_13_n = solver.NumVar(0, infty, "z_5_13_n")
z_5_14_p = solver.NumVar(0, infty, "z_5_14_p")
z_5_14_n = solver.NumVar(0, infty, "z_5_14_n")
z_5_15_p = solver.NumVar(0, infty, "z_5_15_p")
z_5_15_n = solver.NumVar(0, infty, "z_5_15_n")
z_6_1_p = solver.NumVar(0, infty, "z_6_1_p")
z_6_1_n = solver.NumVar(0, infty, "z_6_1_n")
z_6_2_p = solver.NumVar(0, infty, "z_6_2_p")
z_6_2_n = solver.NumVar(0, infty, "z_6_2_n")
z_6_3_p = solver.NumVar(0, infty, "z_6_3_p")
z_6_3_n = solver.NumVar(0, infty, "z_6_3_n")
z_6_4_p = solver.NumVar(0, infty, "z_6_4_p")
z_6_4_n = solver.NumVar(0, infty, "z_6_4_n")
z_6_5_p = solver.NumVar(0, infty, "z_6_5_p")
z_6_5_n = solver.NumVar(0, infty, "z_6_5_n")
z_6_6_p = solver.NumVar(0, infty, "z_6_6_p")
z_6_6_n = solver.NumVar(0, infty, "z_6_6_n")
z_6_7_p = solver.NumVar(0, infty, "z_6_7_p")
z_6_7_n = solver.NumVar(0, infty, "z_6_7_n")
z_6_8_p = solver.NumVar(0, infty, "z_6_8_p")
z_6_8_n = solver.NumVar(0, infty, "z_6_8_n")
z_6_9_p = solver.NumVar(0, infty, "z_6_9_p")
z_6_9_n = solver.NumVar(0, infty, "z_6_9_n")
z_6_10_p = solver.NumVar(0, infty, "z_6_10_p")
z_6_10_n = solver.NumVar(0, infty, "z_6_10_n")
z_6_11_p = solver.NumVar(0, infty, "z_6_11_p")
z_6_11_n = solver.NumVar(0, infty, "z_6_11_n")
z_6_12_p = solver.NumVar(0, infty, "z_6_12_p")
z_6_12_n = solver.NumVar(0, infty, "z_6_12_n")
z_6_13_p = solver.NumVar(0, infty, "z_6_13_p")
z_6_13_n = solver.NumVar(0, infty, "z_6_13_n")
z_6_14_p = solver.NumVar(0, infty, "z_6_14_p")
z_6_14_n = solver.NumVar(0, infty, "z_6_14_n")
z_6_15_p = solver.NumVar(0, infty, "z_6_15_p")
z_6_15_n = solver.NumVar(0, infty, "z_6_15_n")
z_7_1_p = solver.NumVar(0, infty, "z_7_1_p")
z_7_1_n = solver.NumVar(0, infty, "z_7_1_n")
z_7_2_p = solver.NumVar(0, infty, "z_7_2_p")
z_7_2_n = solver.NumVar(0, infty, "z_7_2_n")
z_7_3_p = solver.NumVar(0, infty, "z_7_3_p")
z_7_3_n = solver.NumVar(0, infty, "z_7_3_n")
z_7_4_p = solver.NumVar(0, infty, "z_7_4_p")
z_7_4_n = solver.NumVar(0, infty, "z_7_4_n")
z_7_5_p = solver.NumVar(0, infty, "z_7_5_p")
z_7_5_n = solver.NumVar(0, infty, "z_7_5_n")
z_7_6_p = solver.NumVar(0, infty, "z_7_6_p")
z_7_6_n = solver.NumVar(0, infty, "z_7_6_n")
z_7_7_p = solver.NumVar(0, infty, "z_7_7_p")
z_7_7_n = solver.NumVar(0, infty, "z_7_7_n")
z_7_8_p = solver.NumVar(0, infty, "z_7_8_p")
z_7_8_n = solver.NumVar(0, infty, "z_7_8_n")
z_7_9_p = solver.NumVar(0, infty, "z_7_9_p")
z_7_9_n = solver.NumVar(0, infty, "z_7_9_n")
z_7_10_p = solver.NumVar(0, infty, "z_7_10_p")
z_7_10_n = solver.NumVar(0, infty, "z_7_10_n")
z_7_11_p = solver.NumVar(0, infty, "z_7_11_p")
z_7_11_n = solver.NumVar(0, infty, "z_7_11_n")
z_7_12_p = solver.NumVar(0, infty, "z_7_12_p")
z_7_12_n = solver.NumVar(0, infty, "z_7_12_n")
z_7_13_p = solver.NumVar(0, infty, "z_7_13_p")
z_7_13_n = solver.NumVar(0, infty, "z_7_13_n")
z_7_14_p = solver.NumVar(0, infty, "z_7_14_p")
z_7_14_n = solver.NumVar(0, infty, "z_7_14_n")
z_7_15_p = solver.NumVar(0, infty, "z_7_15_p")
z_7_15_n = solver.NumVar(0, infty, "z_7_15_n")

# %%
A1 = np.array([z_1_1_p,
               z_1_1_n,
               z_1_2_p,
               z_1_2_n,
               z_1_3_p,
               z_1_3_n,
               z_1_4_p,
               z_1_4_n,
               z_1_5_p,
               z_1_5_n,
               z_1_6_p,
               z_1_6_n,
               z_1_7_p,
               z_1_7_n,
               z_1_8_p,
               z_1_8_n,
               z_1_9_p,
               z_1_9_n,
               z_1_10_p,
               z_1_10_n,
               z_1_11_p,
               z_1_11_n,
               z_1_12_p,
               z_1_12_n,
               z_1_13_p,
               z_1_13_n,
               z_1_14_p,
               z_1_14_n,
               z_1_15_p,
               z_1_15_n, ])

A2 = np.array([z_2_1_p,
               z_2_1_n,
               z_2_2_p,
               z_2_2_n,
               z_2_3_p,
               z_2_3_n,
               z_2_4_p,
               z_2_4_n,
               z_2_5_p,
               z_2_5_n,
               z_2_6_p,
               z_2_6_n,
               z_2_7_p,
               z_2_7_n,
               z_2_8_p,
               z_2_8_n,
               z_2_9_p,
               z_2_9_n,
               z_2_10_p,
               z_2_10_n,
               z_2_11_p,
               z_2_11_n,
               z_2_12_p,
               z_2_12_n,
               z_2_13_p,
               z_2_13_n,
               z_2_14_p,
               z_2_14_n,
               z_2_15_p,
               z_2_15_n, ])

A3 = np.array([z_3_1_p,
               z_3_1_n,
               z_3_2_p,
               z_3_2_n,
               z_3_3_p,
               z_3_3_n,
               z_3_4_p,
               z_3_4_n,
               z_3_5_p,
               z_3_5_n,
               z_3_6_p,
               z_3_6_n,
               z_3_7_p,
               z_3_7_n,
               z_3_8_p,
               z_3_8_n,
               z_3_9_p,
               z_3_9_n,
               z_3_10_p,
               z_3_10_n,
               z_3_11_p,
               z_3_11_n,
               z_3_12_p,
               z_3_12_n,
               z_3_13_p,
               z_3_13_n,
               z_3_14_p,
               z_3_14_n,
               z_3_15_p,
               z_3_15_n, ])

A4 = np.array([z_4_1_p,
               z_4_1_n,
               z_4_2_p,
               z_4_2_n,
               z_4_3_p,
               z_4_3_n,
               z_4_4_p,
               z_4_4_n,
               z_4_5_p,
               z_4_5_n,
               z_4_6_p,
               z_4_6_n,
               z_4_7_p,
               z_4_7_n,
               z_4_8_p,
               z_4_8_n,
               z_4_9_p,
               z_4_9_n,
               z_4_10_p,
               z_4_10_n,
               z_4_11_p,
               z_4_11_n,
               z_4_12_p,
               z_4_12_n,
               z_4_13_p,
               z_4_13_n,
               z_4_14_p,
               z_4_14_n,
               z_4_15_p,
               z_4_15_n, ])

A5 = np.array([z_5_1_p,
               z_5_1_n,
               z_5_2_p,
               z_5_2_n,
               z_5_3_p,
               z_5_3_n,
               z_5_4_p,
               z_5_4_n,
               z_5_5_p,
               z_5_5_n,
               z_5_6_p,
               z_5_6_n,
               z_5_7_p,
               z_5_7_n,
               z_5_8_p,
               z_5_8_n,
               z_5_9_p,
               z_5_9_n,
               z_5_10_p,
               z_5_10_n,
               z_5_11_p,
               z_5_11_n,
               z_5_12_p,
               z_5_12_n,
               z_5_13_p,
               z_5_13_n,
               z_5_14_p,
               z_5_14_n,
               z_5_15_p,
               z_5_15_n, ])

A6 = np.array([z_6_1_p,
               z_6_1_n,
               z_6_2_p,
               z_6_2_n,
               z_6_3_p,
               z_6_3_n,
               z_6_4_p,
               z_6_4_n,
               z_6_5_p,
               z_6_5_n,
               z_6_6_p,
               z_6_6_n,
               z_6_7_p,
               z_6_7_n,
               z_6_8_p,
               z_6_8_n,
               z_6_9_p,
               z_6_9_n,
               z_6_10_p,
               z_6_10_n,
               z_6_11_p,
               z_6_11_n,
               z_6_12_p,
               z_6_12_n,
               z_6_13_p,
               z_6_13_n,
               z_6_14_p,
               z_6_14_n,
               z_6_15_p,
               z_6_15_n, ])

A7 = np.array([z_7_1_p,
               z_7_1_n,
               z_7_2_p,
               z_7_2_n,
               z_7_3_p,
               z_7_3_n,
               z_7_4_p,
               z_7_4_n,
               z_7_5_p,
               z_7_5_n,
               z_7_6_p,
               z_7_6_n,
               z_7_7_p,
               z_7_7_n,
               z_7_8_p,
               z_7_8_n,
               z_7_9_p,
               z_7_9_n,
               z_7_10_p,
               z_7_10_n,
               z_7_11_p,
               z_7_11_n,
               z_7_12_p,
               z_7_12_n,
               z_7_13_p,
               z_7_13_n,
               z_7_14_p,
               z_7_14_n,
               z_7_15_p,
               z_7_15_n, ])

# %%
s =np.array([0, 800, 800, 1000, 2000, 2000, 2000, 3000])
p = np.array([0, 160, 155, 155, 160, 155, 150, 160])
A = np.array([A1, A2, A3, A4, A5, A6, A7])
dist = np.array([0, 104, 301, 750, 606, 194, 205, 201, 680, 480, 300, 220, 210, 420, 500])

# %%
dist_1_p = z_1_1_p + z_2_1_p + z_3_1_p + z_4_1_p + z_5_1_p + z_6_1_p + z_7_1_p 

dist_2_n = z_1_2_n + z_2_2_n + z_3_2_n + z_4_2_n + z_5_2_n + z_6_2_n + z_7_2_n 

dist_2_p = z_1_2_p + z_2_2_p + z_3_2_p + z_4_2_p + z_5_2_p + z_6_2_p + z_7_2_p 

dist_3_n = z_1_3_n + z_2_3_n + z_3_3_n + z_4_3_n + z_5_3_n + z_6_3_n + z_7_3_n 

dist_3_p = z_1_3_p + z_2_3_p + z_3_3_p + z_4_3_p + z_5_3_p + z_6_3_p + z_7_3_p 

dist_4_n = z_1_4_n + z_2_4_n + z_3_4_n + z_4_4_n + z_5_4_n + z_6_4_n + z_7_4_n 

dist_4_p = z_1_4_p + z_2_4_p + z_3_4_p + z_4_4_p + z_5_4_p + z_6_4_p + z_7_4_p 

dist_5_n = z_1_5_n + z_2_5_n + z_3_5_n + z_4_5_n + z_5_5_n + z_6_5_n + z_7_5_n 

dist_5_p = z_1_5_p + z_2_5_p + z_3_5_p + z_4_5_p + z_5_5_p + z_6_5_p + z_7_5_p 

dist_6_n = z_1_6_n + z_2_6_n + z_3_6_n + z_4_6_n + z_5_6_n + z_6_6_n + z_7_6_n 

dist_6_p = z_1_6_p + z_2_6_p + z_3_6_p + z_4_6_p + z_5_6_p + z_6_6_p + z_7_6_p 

dist_7_n = z_1_7_n + z_2_7_n + z_3_7_n + z_4_7_n + z_5_7_n + z_6_7_n + z_7_7_n 

dist_7_p = z_1_7_p + z_2_7_p + z_3_7_p + z_4_7_p + z_5_7_p + z_6_7_p + z_7_7_p 

dist_8_n = z_1_8_n + z_2_8_n + z_3_8_n + z_4_8_n + z_5_8_n + z_6_8_n + z_7_8_n 

dist_8_p = z_1_8_p + z_2_8_p + z_3_8_p + z_4_8_p + z_5_8_p + z_6_8_p + z_7_8_p 

dist_9_n = z_1_9_n + z_2_9_n + z_3_9_n + z_4_9_n + z_5_9_n + z_6_9_n + z_7_9_n 

dist_9_p = z_1_9_p + z_2_9_p + z_3_9_p + z_4_9_p + z_5_9_p + z_6_9_p + z_7_9_p 

dist_10_n = z_1_10_n + z_2_10_n + z_3_10_n + z_4_10_n + z_5_10_n + z_6_10_n + z_7_10_n 
dist_10_p = z_1_10_p + z_2_10_p + z_3_10_p + z_4_10_p + z_5_10_p + z_6_10_p + z_7_10_p 
dist_11_n = z_1_11_n + z_2_11_n + z_3_11_n + z_4_11_n + z_5_11_n + z_6_11_n + z_7_11_n 
dist_11_p = z_1_11_p + z_2_11_p + z_3_11_p + z_4_11_p + z_5_11_p + z_6_11_p + z_7_11_p 
dist_12_n = z_1_12_n + z_2_12_n + z_3_12_n + z_4_12_n + z_5_12_n + z_6_12_n + z_7_12_n 
dist_12_p = z_1_12_p + z_2_12_p + z_3_12_p + z_4_12_p + z_5_12_p + z_6_12_p + z_7_12_p 
dist_13_n = z_1_13_n + z_2_13_n + z_3_13_n + z_4_13_n + z_5_13_n + z_6_13_n + z_7_13_n 
dist_13_p = z_1_13_p + z_2_13_p + z_3_13_p + z_4_13_p + z_5_13_p + z_6_13_p + z_7_13_p 
dist_14_n = z_1_14_n + z_2_14_n + z_3_14_n + z_4_14_n + z_5_14_n + z_6_14_n + z_7_14_n 
dist_14_p = z_1_14_p + z_2_14_p + z_3_14_p + z_4_14_p + z_5_14_p + z_6_14_p + z_7_14_p 
dist_15_n = z_1_15_n + z_2_15_n + z_3_15_n + z_4_15_n + z_5_15_n + z_6_15_n + z_7_15_n

# %%
# 约束条件1
solver.Add(500*y1 <= A1.sum())
solver.Add(500*y2 <= A2.sum())
solver.Add(500*y3 <= A3.sum())
solver.Add(500*y4 <= A4.sum())
solver.Add(500*y5 <= A5.sum())
solver.Add(500*y6 <= A6.sum())
solver.Add(500*y7 <= A7.sum())

# 约束条件2
solver.Add(A1.sum() <= s[1]*y1)
solver.Add(A2.sum() <= s[2]*y2)
solver.Add(A3.sum() <= s[3]*y3)
solver.Add(A4.sum() <= s[4]*y4)
solver.Add(A5.sum() <= s[5]*y5)
solver.Add(A6.sum() <= s[6]*y6)
solver.Add(A7.sum() <= s[7]*y7)

# 约束条件3
solver.Add(A.sum() == 5171)

# 约束条件4
solver.Add(z_1_1_n == 0)
solver.Add(z_2_1_n == 0)
solver.Add(z_3_1_n == 0)
solver.Add(z_4_1_n == 0)
solver.Add(z_5_1_n == 0)
solver.Add(z_6_1_n == 0)
solver.Add(z_7_1_n == 0)

solver.Add(z_1_15_p == 0)
solver.Add(z_2_15_p == 0)
solver.Add(z_3_15_p == 0)
solver.Add(z_4_15_p == 0)
solver.Add(z_5_15_p == 0)
solver.Add(z_6_15_p == 0)
solver.Add(z_7_15_p == 0)

# 补充约束 每个节点的要铺满
solver.Add(dist_2_n >= dist[1])
solver.Add(dist_2_p + dist_3_n >= dist[2])
solver.Add(dist_3_p + dist_4_n >= dist[3])
solver.Add(dist_4_p + dist_5_n >= dist[4])
solver.Add(dist_5_p + dist_6_n >= dist[5])
solver.Add(dist_6_p + dist_7_n >= dist[6])
solver.Add(dist_7_p + dist_8_n >= dist[7])
solver.Add(dist_8_p + dist_9_n >= dist[8])
solver.Add(dist_9_p + dist_10_n >= dist[9])
solver.Add(dist_10_p + dist_11_n >= dist[10])
solver.Add(dist_11_p + dist_12_n >= dist[11])
solver.Add(dist_12_p + dist_13_n >= dist[12])
solver.Add(dist_13_p + dist_14_n >= dist[13])
solver.Add(dist_14_p >= dist[14])
# Out:
# <ortools.linear_solver.pywraplp.Constraint; proxy of <Swig Object of type 'operations_research::MPConstraint *' at 0x0000024441A8AF60> >

# %%
s1 = z_1_1_n + z_1_1_p+ z_1_2_n + z_1_2_p+ z_1_3_n + z_1_3_p+ z_1_4_n + z_1_4_p+ z_1_5_n + z_1_5_p+ z_1_6_n + z_1_6_p+ z_1_7_n + z_1_7_p+ z_1_8_n + z_1_8_p+ z_1_9_n + z_1_9_p+ z_1_10_n + z_1_10_p+ z_1_11_n + z_1_11_p+ z_1_12_n + z_1_12_p+ z_1_13_n + z_1_13_p+ z_1_14_n + z_1_14_p+ z_1_15_n + z_1_15_p
s2 = z_2_1_n + z_2_1_p+ z_2_2_n + z_2_2_p+ z_2_3_n + z_2_3_p+ z_2_4_n + z_2_4_p+ z_2_5_n + z_2_5_p+ z_2_6_n + z_2_6_p+ z_2_7_n + z_2_7_p+ z_2_8_n + z_2_8_p+ z_2_9_n + z_2_9_p+ z_2_10_n + z_2_10_p+ z_2_11_n + z_2_11_p+ z_2_12_n + z_2_12_p+ z_2_13_n + z_2_13_p+ z_2_14_n + z_2_14_p+ z_2_15_n + z_2_15_p
s3 = z_3_1_n + z_3_1_p+ z_3_2_n + z_3_2_p+ z_3_3_n + z_3_3_p+ z_3_4_n + z_3_4_p+ z_3_5_n + z_3_5_p+ z_3_6_n + z_3_6_p+ z_3_7_n + z_3_7_p+ z_3_8_n + z_3_8_p+ z_3_9_n + z_3_9_p+ z_3_10_n + z_3_10_p+ z_3_11_n + z_3_11_p+ z_3_12_n + z_3_12_p+ z_3_13_n + z_3_13_p+ z_3_14_n + z_3_14_p+ z_3_15_n + z_3_15_p
s4 = z_4_1_n + z_4_1_p+ z_4_2_n + z_4_2_p+ z_4_3_n + z_4_3_p+ z_4_4_n + z_4_4_p+ z_4_5_n + z_4_5_p+ z_4_6_n + z_4_6_p+ z_4_7_n + z_4_7_p+ z_4_8_n + z_4_8_p+ z_4_9_n + z_4_9_p+ z_4_10_n + z_4_10_p+ z_4_11_n + z_4_11_p+ z_4_12_n + z_4_12_p+ z_4_13_n + z_4_13_p+ z_4_14_n + z_4_14_p+ z_4_15_n + z_4_15_p
s5 = z_5_1_n + z_5_1_p+ z_5_2_n + z_5_2_p+ z_5_3_n + z_5_3_p+ z_5_4_n + z_5_4_p+ z_5_5_n + z_5_5_p+ z_5_6_n + z_5_6_p+ z_5_7_n + z_5_7_p+ z_5_8_n + z_5_8_p+ z_5_9_n + z_5_9_p+ z_5_10_n + z_5_10_p+ z_5_11_n + z_5_11_p+ z_5_12_n + z_5_12_p+ z_5_13_n + z_5_13_p+ z_5_14_n + z_5_14_p+ z_5_15_n + z_5_15_p
s6 = z_6_1_n + z_6_1_p+ z_6_2_n + z_6_2_p+ z_6_3_n + z_6_3_p+ z_6_4_n + z_6_4_p+ z_6_5_n + z_6_5_p+ z_6_6_n + z_6_6_p+ z_6_7_n + z_6_7_p+ z_6_8_n + z_6_8_p+ z_6_9_n + z_6_9_p+ z_6_10_n + z_6_10_p+ z_6_11_n + z_6_11_p+ z_6_12_n + z_6_12_p+ z_6_13_n + z_6_13_p+ z_6_14_n + z_6_14_p+ z_6_15_n + z_6_15_p
s7 = z_7_1_n + z_7_1_p+ z_7_2_n + z_7_2_p+ z_7_3_n + z_7_3_p+ z_7_4_n + z_7_4_p+ z_7_5_n + z_7_5_p+ z_7_6_n + z_7_6_p+ z_7_7_n + z_7_7_p+ z_7_8_n + z_7_8_p+ z_7_9_n + z_7_9_p+ z_7_10_n + z_7_10_p+ z_7_11_n + z_7_11_p+ z_7_12_n + z_7_12_p+ z_7_13_n + z_7_13_p+ z_7_14_n + z_7_14_p+ z_7_15_n + z_7_15_p

# %%
G1 = p[1] * s1 + p[2] * s2 + p[3] * s3 + p[4] * s4 + p[5] * s5 + p[6] * s6 + p[7] * s7
G2 = 160.3 * (z_1_2_n + z_1_2_p) + 140.2 * (z_1_3_n + z_1_3_p) + 86.0 * (z_1_4_n + z_1_4_p) + 38.0 * (z_1_5_n + z_1_5_p) + 20.5 * (z_1_6_n + z_1_6_p) + 21.0 * (z_1_7_n + z_1_7_p) + 21.2 * (z_1_8_n + z_1_8_p) + 64.2 * (z_1_9_n + z_1_9_p) + 92.0 * (z_1_10_n + z_1_10_p) + 101.0 * (z_1_11_n + z_1_11_p) + 106.0 * (z_1_12_n + z_1_12_p) + 121.2 * (z_1_13_n + z_1_13_p) + 128.0 * (z_1_14_n + z_1_14_p) + 142.0 * (z_1_15_n + z_1_15_p) + 210.3 * (z_2_2_n + z_2_2_p) + 190.2 * (z_2_3_n + z_2_3_p) + 136.0 * (z_2_4_n + z_2_4_p) + 111.0 * (z_2_5_n + z_2_5_p) + 95.5 * (z_2_6_n + z_2_6_p) + 86.0 * (z_2_7_n + z_2_7_p) + 76.2 * (z_2_8_n + z_2_8_p) + 114.2 * (z_2_9_n + z_2_9_p) + 142.0 * (z_2_10_n + z_2_10_p) + 131.0 * (z_2_11_n + z_2_11_p) + 156.0 * (z_2_12_n + z_2_12_p) + 171.2 * (z_2_13_n + z_2_13_p) + 178.0 * (z_2_14_n + z_2_14_p) + 192.0 * (z_2_15_n + z_2_15_p) + 220.3 * (z_3_2_n + z_3_2_p) + 200.2 * (z_3_3_n + z_3_3_p) + 146.0 * (z_3_4_n + z_3_4_p) + 121.0 * (z_3_5_n + z_3_5_p) + 105.5 * (z_3_6_n + z_3_6_p) + 96.0 * (z_3_7_n + z_3_7_p) + 86.2 * (z_3_8_n + z_3_8_p) + 48.2 * (z_3_9_n + z_3_9_p) + 82.0 * (z_3_10_n + z_3_10_p) + 86.0 * (z_3_11_n + z_3_11_p) + 96.0 * (z_3_12_n + z_3_12_p) + 111.2 * (z_3_13_n + z_3_13_p) + 118.0 * (z_3_14_n + z_3_14_p) + 132.0 * (z_3_15_n + z_3_15_p) + 255.3 * (z_4_2_n + z_4_2_p) + 235.2 * (z_4_3_n + z_4_3_p) + 181.0 * (z_4_4_n + z_4_4_p) + 156.0 * (z_4_5_n + z_4_5_p) + 140.5 * (z_4_6_n + z_4_6_p) + 131.0 * (z_4_7_n + z_4_7_p) + 121.2 * (z_4_8_n + z_4_8_p) + 84.2 * (z_4_9_n + z_4_9_p) + 62.0 * (z_4_10_n + z_4_10_p) + 51.0 * (z_4_11_n + z_4_11_p) + 61.0 * (z_4_12_n + z_4_12_p) + 76.2 * (z_4_13_n + z_4_13_p) + 83.0 * (z_4_14_n + z_4_14_p) + 97.0 * (z_4_15_n + z_4_15_p) + 225.3 * (z_5_2_n + z_5_2_p) + 245.2 * (z_5_3_n + z_5_3_p) + 171.0 * (z_5_4_n + z_5_4_p) + 146.0 * (z_5_5_n + z_5_5_p) + 130.5 * (z_5_6_n + z_5_6_p) + 121.0 * (z_5_7_n + z_5_7_p) + 111.2 * (z_5_8_n + z_5_8_p) + 79.2 * (z_5_9_n + z_5_9_p) + 57.0 * (z_5_10_n + z_5_10_p) + 33.0 * (z_5_11_n + z_5_11_p) + 51.0 * (z_5_12_n + z_5_12_p) + 71.2 * (z_5_13_n + z_5_13_p) + 73.0 * (z_5_14_n + z_5_14_p) + 87.0 * (z_5_15_n + z_5_15_p) + 255.3 * (z_6_2_n + z_6_2_p) + 235.2 * (z_6_3_n + z_6_3_p) + 181.0 * (z_6_4_n + z_6_4_p) + 156.0 * (z_6_5_n + z_6_5_p) + 140.5 * (z_6_6_n + z_6_6_p) + 131.0 * (z_6_7_n + z_6_7_p) + 121.2 * (z_6_8_n + z_6_8_p) + 89.2 * (z_6_9_n + z_6_9_p) + 62.0 * (z_6_10_n + z_6_10_p) + 51.0 * (z_6_11_n + z_6_11_p) + 45.0 * (z_6_12_n + z_6_12_p) + 26.2 * (z_6_13_n + z_6_13_p) + 31.0 * (z_6_14_n + z_6_14_p) + 28.0 * (z_6_15_n + z_6_15_p) + 265.3 * (z_7_2_n + z_7_2_p) + 250.2 * (z_7_3_n + z_7_3_p) + 191.0 * (z_7_4_n + z_7_4_p) + 166.0 * (z_7_5_n + z_7_5_p) + 150.5 * (z_7_6_n + z_7_6_p) + 141.0 * (z_7_7_n + z_7_7_p) + 131.2 * (z_7_8_n + z_7_8_p) + 99.2 * (z_7_9_n + z_7_9_p) + 77.0 * (z_7_10_n + z_7_10_p) + 66.0 * (z_7_11_n + z_7_11_p) + 56.0 * (z_7_12_n + z_7_12_p) + 38.2 * (z_7_13_n + z_7_13_p) + 26.0 * (z_7_14_n + z_7_14_p) + 22.0 * (z_7_15_n + z_7_15_p)

# %%
solver.Maximize(G1 + G2)

# %%
status = solver.Solve()

# %%
if status == pywraplp.Solver.OPTIMAL:
    print('Solution:')
    print('Objective value =', solver.Objective().Value())
    print('y1 =', y1.solution_value())
    print('y2 =', y2.solution_value())
    print('y3 =', y3.solution_value())
    print('y4 =', y4.solution_value())
    print('y5 =', y5.solution_value())
    print('y6 =', y6.solution_value())
    print('y7 =', y7.solution_value())
    print(" z_1_1_p = ",z_1_1_p.solution_value())
    print(" z_1_1_n = ",z_1_1_p.solution_value())
    print(" z_1_2_p = ",z_1_2_p.solution_value())
    print(" z_1_2_n = ",z_1_2_p.solution_value())
    print(" z_1_3_p = ",z_1_3_p.solution_value())
    print(" z_1_3_n = ",z_1_3_p.solution_value())
    print(" z_1_4_p = ",z_1_4_p.solution_value())
    print(" z_1_4_n = ",z_1_4_p.solution_value())
    print(" z_1_5_p = ",z_1_5_p.solution_value())
    print(" z_1_5_n = ",z_1_5_p.solution_value())
    print(" z_1_6_p = ",z_1_6_p.solution_value())
    print(" z_1_6_n = ",z_1_6_p.solution_value())
    print(" z_1_7_p = ",z_1_7_p.solution_value())
    print(" z_1_7_n = ",z_1_7_p.solution_value())
    print(" z_1_8_p = ",z_1_8_p.solution_value())
    print(" z_1_8_n = ",z_1_8_p.solution_value())
    print(" z_1_9_p = ",z_1_9_p.solution_value())
    print(" z_1_9_n = ",z_1_9_p.solution_value())
    print(" z_1_10_p = ",z_1_10_p.solution_value())
    print(" z_1_10_n = ",z_1_10_p.solution_value())
    print(" z_1_11_p = ",z_1_11_p.solution_value())
    print(" z_1_11_n = ",z_1_11_p.solution_value())
    print(" z_1_12_p = ",z_1_12_p.solution_value())
    print(" z_1_12_n = ",z_1_12_p.solution_value())
    print(" z_1_13_p = ",z_1_13_p.solution_value())
    print(" z_1_13_n = ",z_1_13_p.solution_value())
    print(" z_1_14_p = ",z_1_14_p.solution_value())
    print(" z_1_14_n = ",z_1_14_p.solution_value())
    print(" z_1_15_p = ",z_1_15_p.solution_value())
    print(" z_1_15_n = ",z_1_15_p.solution_value())
    print(" z_2_1_p = ",z_2_1_p.solution_value())
    print(" z_2_1_n = ",z_2_1_p.solution_value())
    print(" z_2_2_p = ",z_2_2_p.solution_value())
    print(" z_2_2_n = ",z_2_2_p.solution_value())
    print(" z_2_3_p = ",z_2_3_p.solution_value())
    print(" z_2_3_n = ",z_2_3_p.solution_value())
    print(" z_2_4_p = ",z_2_4_p.solution_value())
    print(" z_2_4_n = ",z_2_4_p.solution_value())
    print(" z_2_5_p = ",z_2_5_p.solution_value())
    print(" z_2_5_n = ",z_2_5_p.solution_value())
    print(" z_2_6_p = ",z_2_6_p.solution_value())
    print(" z_2_6_n = ",z_2_6_p.solution_value())
    print(" z_2_7_p = ",z_2_7_p.solution_value())
    print(" z_2_7_n = ",z_2_7_p.solution_value())
    print(" z_2_8_p = ",z_2_8_p.solution_value())
    print(" z_2_8_n = ",z_2_8_p.solution_value())
    print(" z_2_9_p = ",z_2_9_p.solution_value())
    print(" z_2_9_n = ",z_2_9_p.solution_value())
    print(" z_2_10_p = ",z_2_10_p.solution_value())
    print(" z_2_10_n = ",z_2_10_p.solution_value())
    print(" z_2_11_p = ",z_2_11_p.solution_value())
    print(" z_2_11_n = ",z_2_11_p.solution_value())
    print(" z_2_12_p = ",z_2_12_p.solution_value())
    print(" z_2_12_n = ",z_2_12_p.solution_value())
    print(" z_2_13_p = ",z_2_13_p.solution_value())
    print(" z_2_13_n = ",z_2_13_p.solution_value())
    print(" z_2_14_p = ",z_2_14_p.solution_value())
    print(" z_2_14_n = ",z_2_14_p.solution_value())
    print(" z_2_15_p = ",z_2_15_p.solution_value())
    print(" z_2_15_n = ",z_2_15_p.solution_value())
    print(" z_3_1_p = ",z_3_1_p.solution_value())
    print(" z_3_1_n = ",z_3_1_p.solution_value())
    print(" z_3_2_p = ",z_3_2_p.solution_value())
    print(" z_3_2_n = ",z_3_2_p.solution_value())
    print(" z_3_3_p = ",z_3_3_p.solution_value())
    print(" z_3_3_n = ",z_3_3_p.solution_value())
    print(" z_3_4_p = ",z_3_4_p.solution_value())
    print(" z_3_4_n = ",z_3_4_p.solution_value())
    print(" z_3_5_p = ",z_3_5_p.solution_value())
    print(" z_3_5_n = ",z_3_5_p.solution_value())
    print(" z_3_6_p = ",z_3_6_p.solution_value())
    print(" z_3_6_n = ",z_3_6_p.solution_value())
    print(" z_3_7_p = ",z_3_7_p.solution_value())
    print(" z_3_7_n = ",z_3_7_p.solution_value())
    print(" z_3_8_p = ",z_3_8_p.solution_value())
    print(" z_3_8_n = ",z_3_8_p.solution_value())
    print(" z_3_9_p = ",z_3_9_p.solution_value())
    print(" z_3_9_n = ",z_3_9_p.solution_value())
    print(" z_3_10_p = ",z_3_10_p.solution_value())
    print(" z_3_10_n = ",z_3_10_p.solution_value())
    print(" z_3_11_p = ",z_3_11_p.solution_value())
    print(" z_3_11_n = ",z_3_11_p.solution_value())
    print(" z_3_12_p = ",z_3_12_p.solution_value())
    print(" z_3_12_n = ",z_3_12_p.solution_value())
    print(" z_3_13_p = ",z_3_13_p.solution_value())
    print(" z_3_13_n = ",z_3_13_p.solution_value())
    print(" z_3_14_p = ",z_3_14_p.solution_value())
    print(" z_3_14_n = ",z_3_14_p.solution_value())
    print(" z_3_15_p = ",z_3_15_p.solution_value())
    print(" z_3_15_n = ",z_3_15_p.solution_value())
    print(" z_4_1_p = ",z_4_1_p.solution_value())
    print(" z_4_1_n = ",z_4_1_p.solution_value())
    print(" z_4_2_p = ",z_4_2_p.solution_value())
    print(" z_4_2_n = ",z_4_2_p.solution_value())
    print(" z_4_3_p = ",z_4_3_p.solution_value())
    print(" z_4_3_n = ",z_4_3_p.solution_value())
    print(" z_4_4_p = ",z_4_4_p.solution_value())
    print(" z_4_4_n = ",z_4_4_p.solution_value())
    print(" z_4_5_p = ",z_4_5_p.solution_value())
    print(" z_4_5_n = ",z_4_5_p.solution_value())
    print(" z_4_6_p = ",z_4_6_p.solution_value())
    print(" z_4_6_n = ",z_4_6_p.solution_value())
    print(" z_4_7_p = ",z_4_7_p.solution_value())
    print(" z_4_7_n = ",z_4_7_p.solution_value())
    print(" z_4_8_p = ",z_4_8_p.solution_value())
    print(" z_4_8_n = ",z_4_8_p.solution_value())
    print(" z_4_9_p = ",z_4_9_p.solution_value())
    print(" z_4_9_n = ",z_4_9_p.solution_value())
    print(" z_4_10_p = ",z_4_10_p.solution_value())
    print(" z_4_10_n = ",z_4_10_p.solution_value())
    print(" z_4_11_p = ",z_4_11_p.solution_value())
    print(" z_4_11_n = ",z_4_11_p.solution_value())
    print(" z_4_12_p = ",z_4_12_p.solution_value())
    print(" z_4_12_n = ",z_4_12_p.solution_value())
    print(" z_4_13_p = ",z_4_13_p.solution_value())
    print(" z_4_13_n = ",z_4_13_p.solution_value())
    print(" z_4_14_p = ",z_4_14_p.solution_value())
    print(" z_4_14_n = ",z_4_14_p.solution_value())
    print(" z_4_15_p = ",z_4_15_p.solution_value())
    print(" z_4_15_n = ",z_4_15_p.solution_value())
    print(" z_5_1_p = ",z_5_1_p.solution_value())
    print(" z_5_1_n = ",z_5_1_p.solution_value())
    print(" z_5_2_p = ",z_5_2_p.solution_value())
    print(" z_5_2_n = ",z_5_2_p.solution_value())
    print(" z_5_3_p = ",z_5_3_p.solution_value())
    print(" z_5_3_n = ",z_5_3_p.solution_value())
    print(" z_5_4_p = ",z_5_4_p.solution_value())
    print(" z_5_4_n = ",z_5_4_p.solution_value())
    print(" z_5_5_p = ",z_5_5_p.solution_value())
    print(" z_5_5_n = ",z_5_5_p.solution_value())
    print(" z_5_6_p = ",z_5_6_p.solution_value())
    print(" z_5_6_n = ",z_5_6_p.solution_value())
    print(" z_5_7_p = ",z_5_7_p.solution_value())
    print(" z_5_7_n = ",z_5_7_p.solution_value())
    print(" z_5_8_p = ",z_5_8_p.solution_value())
    print(" z_5_8_n = ",z_5_8_p.solution_value())
    print(" z_5_9_p = ",z_5_9_p.solution_value())
    print(" z_5_9_n = ",z_5_9_p.solution_value())
    print(" z_5_10_p = ",z_5_10_p.solution_value())
    print(" z_5_10_n = ",z_5_10_p.solution_value())
    print(" z_5_11_p = ",z_5_11_p.solution_value())
    print(" z_5_11_n = ",z_5_11_p.solution_value())
    print(" z_5_12_p = ",z_5_12_p.solution_value())
    print(" z_5_12_n = ",z_5_12_p.solution_value())
    print(" z_5_13_p = ",z_5_13_p.solution_value())
    print(" z_5_13_n = ",z_5_13_p.solution_value())
    print(" z_5_14_p = ",z_5_14_p.solution_value())
    print(" z_5_14_n = ",z_5_14_p.solution_value())
    print(" z_5_15_p = ",z_5_15_p.solution_value())
    print(" z_5_15_n = ",z_5_15_p.solution_value())
    print(" z_6_1_p = ",z_6_1_p.solution_value())
    print(" z_6_1_n = ",z_6_1_p.solution_value())
    print(" z_6_2_p = ",z_6_2_p.solution_value())
    print(" z_6_2_n = ",z_6_2_p.solution_value())
    print(" z_6_3_p = ",z_6_3_p.solution_value())
    print(" z_6_3_n = ",z_6_3_p.solution_value())
    print(" z_6_4_p = ",z_6_4_p.solution_value())
    print(" z_6_4_n = ",z_6_4_p.solution_value())
    print(" z_6_5_p = ",z_6_5_p.solution_value())
    print(" z_6_5_n = ",z_6_5_p.solution_value())
    print(" z_6_6_p = ",z_6_6_p.solution_value())
    print(" z_6_6_n = ",z_6_6_p.solution_value())
    print(" z_6_7_p = ",z_6_7_p.solution_value())
    print(" z_6_7_n = ",z_6_7_p.solution_value())
    print(" z_6_8_p = ",z_6_8_p.solution_value())
    print(" z_6_8_n = ",z_6_8_p.solution_value())
    print(" z_6_9_p = ",z_6_9_p.solution_value())
    print(" z_6_9_n = ",z_6_9_p.solution_value())
    print(" z_6_10_p = ",z_6_10_p.solution_value())
    print(" z_6_10_n = ",z_6_10_p.solution_value())
    print(" z_6_11_p = ",z_6_11_p.solution_value())
    print(" z_6_11_n = ",z_6_11_p.solution_value())
    print(" z_6_12_p = ",z_6_12_p.solution_value())
    print(" z_6_12_n = ",z_6_12_p.solution_value())
    print(" z_6_13_p = ",z_6_13_p.solution_value())
    print(" z_6_13_n = ",z_6_13_p.solution_value())
    print(" z_6_14_p = ",z_6_14_p.solution_value())
    print(" z_6_14_n = ",z_6_14_p.solution_value())
    print(" z_6_15_p = ",z_6_15_p.solution_value())
    print(" z_6_15_n = ",z_6_15_p.solution_value())
    print(" z_7_1_p = ",z_7_1_p.solution_value())
    print(" z_7_1_n = ",z_7_1_p.solution_value())
    print(" z_7_2_p = ",z_7_2_p.solution_value())
    print(" z_7_2_n = ",z_7_2_p.solution_value())
    print(" z_7_3_p = ",z_7_3_p.solution_value())
    print(" z_7_3_n = ",z_7_3_p.solution_value())
    print(" z_7_4_p = ",z_7_4_p.solution_value())
    print(" z_7_4_n = ",z_7_4_p.solution_value())
    print(" z_7_5_p = ",z_7_5_p.solution_value())
    print(" z_7_5_n = ",z_7_5_p.solution_value())
    print(" z_7_6_p = ",z_7_6_p.solution_value())
    print(" z_7_6_n = ",z_7_6_p.solution_value())
    print(" z_7_7_p = ",z_7_7_p.solution_value())
    print(" z_7_7_n = ",z_7_7_p.solution_value())
    print(" z_7_8_p = ",z_7_8_p.solution_value())
    print(" z_7_8_n = ",z_7_8_p.solution_value())
    print(" z_7_9_p = ",z_7_9_p.solution_value())
    print(" z_7_9_n = ",z_7_9_p.solution_value())
    print(" z_7_10_p = ",z_7_10_p.solution_value())
    print(" z_7_10_n = ",z_7_10_p.solution_value())
    print(" z_7_11_p = ",z_7_11_p.solution_value())
    print(" z_7_11_n = ",z_7_11_p.solution_value())
    print(" z_7_12_p = ",z_7_12_p.solution_value())
    print(" z_7_12_n = ",z_7_12_p.solution_value())
    print(" z_7_13_p = ",z_7_13_p.solution_value())
    print(" z_7_13_n = ",z_7_13_p.solution_value())
    print(" z_7_14_p = ",z_7_14_p.solution_value())
    print(" z_7_14_n = ",z_7_14_p.solution_value())
    print(" z_7_15_p = ",z_7_15_p.solution_value())
    print(" z_7_15_n = ",z_7_15_p.solution_value())
else:
    print('The problem does not have an optimal solution.')
# Out:
# Solution:
# Objective value = 1692353.9999999998
# y1 = 1.0
# y2 = 1.0
# y3 = 0.0
# y4 = 1.0
# y5 = 0.0
# y6 = 0.0
# y7 = 1.0
#  z_1_1_p =  0.0
#  z_1_1_n =  0.0
#  z_1_2_p =  0.0
#  z_1_2_n =  0.0
#  z_1_3_p =  0.0
#  z_1_3_n =  0.0
#  z_1_4_p =  0.0
#  z_1_4_n =  0.0
#  z_1_5_p =  0.0
#  z_1_5_n =  0.0
#  z_1_6_p =  0.0
#  z_1_6_n =  0.0
#  z_1_7_p =  0.0
#  z_1_7_n =  0.0
#  z_1_8_p =  0.0
#  z_1_8_n =  0.0
#  z_1_9_p =  0.0
#  z_1_9_n =  0.0
#  z_1_10_p =  0.0
#  z_1_10_n =  0.0
#  z_1_11_p =  0.0
#  z_1_11_n =  0.0
#  z_1_12_p =  0.0
#  z_1_12_n =  0.0
#  z_1_13_p =  0.0
#  z_1_13_n =  0.0
#  z_1_14_p =  500.0000000000001
#  z_1_14_n =  500.0000000000001
#  z_1_15_p =  0.0
#  z_1_15_n =  0.0
#  z_2_1_p =  0.0
#  z_2_1_n =  0.0
#  z_2_2_p =  0.0
#  z_2_2_n =  0.0
#  z_2_3_p =  0.0
#  z_2_3_n =  0.0
#  z_2_4_p =  0.0
#  z_2_4_n =  0.0
#  z_2_5_p =  0.0
#  z_2_5_n =  0.0
#  z_2_6_p =  0.0
#  z_2_6_n =  0.0
#  z_2_7_p =  0.0
#  z_2_7_n =  0.0
#  z_2_8_p =  0.0
#  z_2_8_n =  0.0
# ...
